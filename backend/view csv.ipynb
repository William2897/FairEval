# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\FairEval Model Development\\RMP_SET-Labelled_SA.csv")
df_2 = pd.read_csv("professors_75346_processed.csv")

# %%
df.head()
# Out:
#                                       rating_comment  \
# 0  Everyone knows that Anatomy and physiology 1 a...
# 1  Absolutely loved taking her class. She's an in...
# 2  Dr.A gives great lectures and you really learn...
# 3  Great professor. She was difficult for sure, b...
# 4  Dr. A is a very smart professor. Be prepared t...
#
#                                    processed_comment  sentiment  confidence
# 0  ['everyone', 'know', 'anatomy', 'physiology', ...          1      0.9985
# 1  ['absolutely', 'love', 'take', 'incredible', '...          1      0.9990
# 2  ['dra', 'give', 'great', 'lecture', 'really', ...          1      0.9990
# 3  ['great', 'difficult', 'sure', 'literally', 'r...          1      0.9990
# 4  ['smart', 'prepare', 'read', 'book', 'hour', '...          1      0.9976

# %%
df_2.columns
# Out:
# Index(['professor_id', 'department', 'first_name', 'last_name',
#        'would_take_again_percent', 'avg_rating', 'rating_comment',
#        'flag_status', 'rating_class', 'helpful_rating', 'clarity_rating',
#        'is_online', 'difficulty_rating', 'is_for_credit', 'sentiment',
#        'confidence', 'gender', 'discipline', 'sub_discipline',
#        'processed_comment', 'processed_tokens', 'positive_terms_lexicon',
#        'negative_terms_lexicon', 'positive_terms_vader',
#        'negative_terms_vader'],
#       dtype='object')

# %%
df_2.head()
# Out:
#    professor_id department first_name   last_name  would_take_again_percent  \
# 0        600026    Biology     Angela  Asirvatham                   85.7143
# 1        600026    Biology     Angela  Asirvatham                   85.7143
# 2        600026    Biology     Angela  Asirvatham                   85.7143
# 3        600026    Biology     Angela  Asirvatham                   85.7143
# 4        600026    Biology     Angela  Asirvatham                   85.7143
#
#    avg_rating                                     rating_comment flag_status  \
# 0         3.7  Everyone knows that Anatomy and physiology 1 a...   UNFLAGGED
# 1         3.7  Absolutely loved taking her class. She's an in...   UNFLAGGED
# 2         3.7  Dr.A gives great lectures and you really learn...   UNFLAGGED
# 3         3.7  Great professor. She was difficult for sure, b...   UNFLAGGED
# 4         3.7  Dr. A is a very smart professor. Be prepared t...   UNFLAGGED
#
# ...
